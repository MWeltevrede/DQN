# %%
from model import DDQN
from dqn import DeepQLearning
from atari_wrappers import PongWrapper

import torch
import numpy as np

import os, random

# %%
image_size = 42
stack_size = 4      # number of consecutive frames stacked


lr = 0.00025
gamma = 0.99

train_freq = 4
replay_buffer_size = 10000
initial_replay_buffer_size = 10000
target_update_freq = 1000

total_steps = int(5e5)
max_steps_per_ep = 50000
batch_size = 32*train_freq 

initial_epsilon = 1.0
final_epsilon = 0.01
num_decay_steps = 1e5

log_path = "tensorboard/ddqn/pong"
save_freq = 100000
save_path = "models/ddqn"
if not os.path.isdir(save_path):
    os.mkdir(save_path)


device = torch.device('cpu')
if torch.cuda.is_available():
    device = torch.device('cuda')
    
env = PongWrapper({'env_name': "PongDeterministic-v4",'image_size':image_size, 'stack_size':stack_size})

seed = 0

env.env.seed(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
    
dqn = DDQN((stack_size, image_size, image_size), env.action_space.n, np.array([[32,4,2,0], [64,4,2,0], [64,3,1,0]]), [512]).to(device)

deepQ = DeepQLearning(env, 
                      dqn, 
                      total_steps=total_steps, replay_buffer_size=replay_buffer_size, 
                      initial_buffer_size=initial_replay_buffer_size, 
                      train_freq=train_freq, 
                      target_update_freq=target_update_freq, 
                      gamma=gamma, 
                      lr=lr, 
                      batch_size=batch_size,
                      max_steps_per_ep=max_steps_per_ep, 
                      initial_epsilon=initial_epsilon, 
                      final_epsilon=final_epsilon, 
                      num_decay_steps=num_decay_steps, 
                      save_freq=save_freq, 
                      save_path=save_path, 
                      log_path=log_path, 
                      device=device)

# %%
deepQ.train()
# Out:
# Frame ID: 10000, episode: 163, average return last 100 episodes: -0.98, fps: 298.8844643084881
# Frame ID: 20000, episode: 325, average return last 100 episodes: -0.98, fps: 290.26945672814605
# Frame ID: 30000, episode: 467, average return last 100 episodes: -0.94, fps: 281.9138671452645
# Frame ID: 40000, episode: 601, average return last 100 episodes: -0.95, fps: 274.08181234643257
# Frame ID: 50000, episode: 729, average return last 100 episodes: -0.96, fps: 267.8911851225067
# Frame ID: 60000, episode: 841, average return last 100 episodes: -0.92, fps: 261.7069510274526
# Frame ID: 70000, episode: 951, average return last 100 episodes: -0.91, fps: 256.25869351754733
# Frame ID: 80000, episode: 1033, average return last 100 episodes: -0.79, fps: 251.26356260813026
# Frame ID: 90000, episode: 1113, average return last 100 episodes: -0.82, fps: 247.00507248672977
# Frame ID: 100000, episode: 1173, average return last 100 episodes: -0.71, fps: 242.39373064848985
# Saved model at step: 100000
# Frame ID: 110000, episode: 1228, average return last 100 episodes: -0.72, fps: 238.81729282560596
# Frame ID: 120000, episode: 1277, average return last 100 episodes: -0.54, fps: 236.25617754177145
# Frame ID: 130000, episode: 1322, average return last 100 episodes: -0.37, fps: 234.23370445506896
# Frame ID: 140000, episode: 1375, average return last 100 episodes: -0.21, fps: 232.60401408709208
# Frame ID: 150000, episode: 1411, average return last 100 episodes: 0.16, fps: 230.96288251108757
# Frame ID: 160000, episode: 1447, average return last 100 episodes: 0.66, fps: 229.4260052238365
# Frame ID: 170000, episode: 1480, average return last 100 episodes: 1.11, fps: 228.51586089125658
# Frame ID: 180000, episode: 1513, average return last 100 episodes: 1.32, fps: 227.46453559859972
# Frame ID: 190000, episode: 1538, average return last 100 episodes: 1.76, fps: 226.67349889189137
# Frame ID: 200000, episode: 1559, average return last 100 episodes: 1.92, fps: 226.0056143371762
# Saved model at step: 200000
# Frame ID: 210000, episode: 1571, average return last 100 episodes: 2.8, fps: 225.48148438882754
# Frame ID: 220000, episode: 1590, average return last 100 episodes: 3.24, fps: 224.95805311665686
# Frame ID: 230000, episode: 1599, average return last 100 episodes: 4.53, fps: 224.32913010509438
# Frame ID: 240000, episode: 1615, average return last 100 episodes: 5.22, fps: 223.8757847470312
# Frame ID: 250000, episode: 1635, average return last 100 episodes: 5.54, fps: 223.30394759115876
# Frame ID: 260000, episode: 1647, average return last 100 episodes: 6.25, fps: 222.8323955300947
# Frame ID: 270000, episode: 1666, average return last 100 episodes: 6.24, fps: 222.36161372987257
# Frame ID: 280000, episode: 1676, average return last 100 episodes: 6.6, fps: 221.93722684504883
# Frame ID: 290000, episode: 1687, average return last 100 episodes: 7.43, fps: 221.63056175755167
# Frame ID: 300000, episode: 1703, average return last 100 episodes: 6.76, fps: 221.32357729039103
# Saved model at step: 300000
# Frame ID: 310000, episode: 1721, average return last 100 episodes: 6.7, fps: 220.94931567609183
# Frame ID: 320000, episode: 1733, average return last 100 episodes: 7.19, fps: 220.73516844299104
# Frame ID: 330000, episode: 1741, average return last 100 episodes: 7.68, fps: 220.56089151427304
# Frame ID: 340000, episode: 1748, average return last 100 episodes: 8.26, fps: 220.4417223288124
# Frame ID: 350000, episode: 1768, average return last 100 episodes: 8.47, fps: 220.25079247963868
# Frame ID: 360000, episode: 1782, average return last 100 episodes: 7.85, fps: 220.0877016765755
# Frame ID: 370000, episode: 1797, average return last 100 episodes: 7.82, fps: 219.80712980855017
# Frame ID: 380000, episode: 1812, average return last 100 episodes: 7.98, fps: 219.51188027461603
# Frame ID: 390000, episode: 1822, average return last 100 episodes: 8.53, fps: 219.2481753714721
# Frame ID: 400000, episode: 1829, average return last 100 episodes: 8.99, fps: 219.12107032924334
# Saved model at step: 400000
# Frame ID: 410000, episode: 1839, average return last 100 episodes: 9.19, fps: 218.87988423847014
# Frame ID: 420000, episode: 1855, average return last 100 episodes: 8.05, fps: 218.65740582380633
# Frame ID: 430000, episode: 1863, average return last 100 episodes: 8.88, fps: 218.58339797422744
# Frame ID: 440000, episode: 1875, average return last 100 episodes: 9.11, fps: 218.54584750544788
# Frame ID: 450000, episode: 1889, average return last 100 episodes: 9.51, fps: 218.35878342410453
# Frame ID: 460000, episode: 1897, average return last 100 episodes: 10.1, fps: 218.24141037256152
# Frame ID: 470000, episode: 1905, average return last 100 episodes: 10.8, fps: 218.23202724293537
# Frame ID: 480000, episode: 1918, average return last 100 episodes: 10.55, fps: 218.095144030459
# Frame ID: 490000, episode: 1932, average return last 100 episodes: 9.68, fps: 217.9221410958738
# Frame ID: 500000, episode: 1946, average return last 100 episodes: 9.49, fps: 217.72996433266815
# Saved model at step: 500000
